# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
#Loading the image to be tested
image = cv2.imread(r'C:\Users\sreenish\Documents\manasa\face detector\baby1.jpg',0)

# %%
plt.imshow(image,cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('haarcascade/haarcascade_frontalface_default.xml')

# %%
def detect_face(img):
    
    face_img = img.copy()
    
    face_rects = face_cascade.detectmultiscale(face_img)

    for (x,y,w,h) in face_rects:
    
        cv2.rectangle(face_img,(x,y),(x+w,y+h),(255,255,255),10)
    
    return face_img

# %%
  plt.imshow(image,cmap='gray')

# %%
plt.figure(figsize=(20,25))
plt.imshow(image)
plt.show()

# %%
plt.figure(figsize=(18,15))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
face2=cv2.imread(r'C:\Users\sreenish\Documents\manasa\face detector\face2.png')

# %%
plt.figure(figsize=(20,25))
plt.imshow(face2)
plt.show()

# %%
C:\Users\sreenish\Documents\manasa\face detector
